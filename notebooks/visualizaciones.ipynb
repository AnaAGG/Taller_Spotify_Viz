# %% [markdown]
# - radar plot
# - que generos se escuchaban por decada
#
# https://github.com/jmcabreira-zz/A-Music-Taste-Analysis-Using-Spotify-API-and-Python./blob/master/Playlist_analysis_%20.ipynb

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# para ver todas las columnas del dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# | Característica | Significado |
# |---|---|
# |**Danceability**   |  Describe lo adecuada que es una pista para bailar basándose en una combinación de elementos musicales como el tempo, la estabilidad del ritmo, la fuerza del compás y la regularidad general. Un valor de 0 es el menos bailable y 1 el más bailable.
# | **Acousticness**  |  Una medida de 0 a 1 que indica si la pista es acústica. |
# |**Energy**   |  Es una medida de 0 a 1 y representa una medida perceptiva de intensidad y actividad. Normalmente, las pistas energéticas son rápidas, fuertes y ruidosas.|
# |**Instrumentalness** |Predice si una pista no contiene voces. Cuanto más se acerque el valor de instrumental a 1,0, mayor será la probabilidad de que la pista no contenga voces.   |
# | **Liveness**| Detecta la presencia de público en la grabación. Los valores más altos representan una mayor probabilidad de que la pista se haya grabado en directo.   |
# | **Loudness**| La sonoridad general de una pista en decibelios (dB). Los valores de sonoridad se promedian en toda la pista. Los valores típicos oscilan entre -60 y 0 dB.  |
# |**Speechiness** | La sonoridad detecta la presencia de palabras habladas en una pista. Cuanto más exclusivamente hablada sea la grabación (por ejemplo, un programa de entrevistas, un audiolibro o poesía), más se acercará a 1 el valor del atributo.  |
# | **Tempo** |  En terminología musical, el tempo es la velocidad o el ritmo de una pieza determinada y se deriva directamente de la duración media de los tiempos.   |
# | **Valence**| De 0 a 1 que describe la positividad musical que transmite una pista. Las pistas con valencia alta suenan más positivas (por ejemplo, felices, alegres, eufóricas), mientras que las pistas con valencia baja suenan más negativas (por ejemplo, tristes, deprimidas, enfadadas).    |

# %%
df1 = pd.read_csv("../data/basic_info_2023-04-28_lo mejor de los 80.csv", index_col=0)
df2 = pd.read_csv("../data/basic_info_2023-04-28_lo mejor de los 90 españa.csv", index_col=0)
df3 = pd.read_csv("../data/basic_info_2023-04-28_lo mejor de los 90 ingles.csv", index_col=0)
df4 = pd.read_csv("../data/basic_info_2023-04-28_lo mejor de los 90 internacional.csv", index_col=0)
df5 = pd.read_csv("../data/basic_info_2023-04-28_musica de los 70,80,90.csv", index_col=0)
df6 = pd.read_csv("../data/basic_info_2023-04-28_musica de los 70.csv", index_col=0)
df7 = pd.read_csv("../data/basic_info_2023-04-28_musica de los 80 españa.csv", index_col=0)
df8 = pd.read_csv("../data/basic_info_2023-05-02_lo mejor de los 90 ingles.csv", index_col=0)
df9 = pd.read_csv("../data/basic_info_2023-04-28_musica de los 80.csv", index_col=0)
df12 = pd.read_csv("../data/basic_info_2023-05-02_musica de los 2010 en ingles.csv", index_col=0)
df13 = pd.read_csv("../data/basic_info_2023-05-02_musica disco de los 2000.csv", index_col=0)
df14 = pd.read_csv("../data/basic_info_2023-05-02_os mejores exitos del 2000.csv", index_col=0)
df15 = pd.read_csv("../data/basic_info_2023-05-02_musica de los 60.csv", index_col = 0)

# %%
df22 = pd.concat([df2, df12, df13, df14, df1, df3, df4, df5, df6, df7, df8, df9, df15], axis=0)
df22.head()
# Out:
#                                              song                artist  \
# 0                                    Estoy por ti  Amistades Peligrosas
# 1  Vivimos siempre juntos (feat. Mercedes Ferrer)            Nacho Cano
# 1  Vivimos siempre juntos (feat. Mercedes Ferrer)            Nacho Cano
# 1  Vivimos siempre juntos (feat. Mercedes Ferrer)       Mercedes Ferrer
# 1  Vivimos siempre juntos (feat. Mercedes Ferrer)       Mercedes Ferrer
#
#          date  explicit                           uri_cancion  popularity  \
# 0        1991     False  spotify:track:2NCw456Y6nu6RgPotF5tDG          48
# 1  1996-10-14     False  spotify:track:6ijh6CO529euKaq3YfSuCZ          54
# 1  1996-10-14     False  spotify:track:6ijh6CO529euKaq3YfSuCZ          54
# 1  1996-10-14     False  spotify:track:6ijh6CO529euKaq3YfSuCZ          54
# 1  1996-10-14     False  spotify:track:6ijh6CO529euKaq3YfSuCZ          54
#
#                      usuario  \
# 0  oid6yv3v6mpo5t94nn5bqblvq
# ...

# %%
df22.dropna(inplace=True)
df22.reset_index(drop = True, inplace=True)

# %%
df22.index
# Out:
# RangeIndex(start=0, stop=2734, step=1)

# %%
df22.to_csv("../data/musica_taller.csv", index=False)

# %%
import glob
import os

all_files = glob.glob(os.path.join("../data/" , "*.csv"))
all_files.sort()
all_files = all_files[33:-2]
all_files
# Out:
# ['../data/info_artistas_2023-04-26.csv',
#  '../data/info_artistas_2023-04-28_lo mejor de los 80.csv',
#  '../data/info_artistas_2023-04-28_lo mejor de los 90 españa.csv',
#  '../data/info_artistas_2023-04-28_lo mejor de los 90 internacional.csv',
#  '../data/info_artistas_2023-04-28_musica de los 70,80,90.csv',
#  '../data/info_artistas_2023-04-28_musica de los 70.csv',
#  '../data/info_artistas_2023-04-28_musica de los 80 españa.csv',
#  '../data/info_artistas_2023-05-02_lo mejor de los 90 ingles.csv',
#  '../data/info_artistas_2023-05-02_los 2000 en españa.csv',
#  '../data/info_artistas_2023-05-02_musica de los 2010 en español.csv',
#  '../data/info_artistas_2023-05-02_musica de los 2010 en ingles.csv',
#  '../data/info_artistas_2023-05-02_musica de los 60.csv',
#  '../data/info_artistas_2023-05-02_musica disco de los 2000.csv',
#  '../data/info_artistas_2023-05-02_os mejores exitos del 2000.csv']

# %%
df_artistas = pd.DataFrame()
for i in all_files:
    dff = pd.read_csv(i, index_col = 0)
    df_artistas = pd.concat([dff, df_artistas], axis = 0)
    df_artistas.reset_index(drop = True, inplace = True)

# %%
df_artistas.head()
# Out:
#     artist_name               artist_id  followers  \
# 0       Rihanna  5pKCCKE2ajJHZ9KAiaK11H   54752804
# 1         JAY-Z  3nFkdlSjzX9mRTtwJOzDYB    8330852
# 2   Miley Cyrus  5YGY8feqx7naU7z4HrwZM6   20548132
# 3  Nena Daconte  58ZTr51uERVdMQbfDbc5B3     157076
# 4     Lady Gaga  1HY2Jd0NmPuamShAr6KMms   26207886
#
#                                               genres  popularity
# 0     ['barbadian pop', 'pop', 'urban contemporary']          91
# 1  ['east coast hip hop', 'gangster rap', 'hip ho...          85
# 2                                            ['pop']          90
# 3                                    ['spanish pop']          52
# 4                    ['art pop', 'dance pop', 'pop']          86

# %%
df_artistas.to_csv("../data/artistas_taller.csv", index = False)

# %% [markdown]
# ----------------------

# %% [markdown]
# # Exploración del conjunto de datos

# %%
df = pd.read_csv("../data/musica_taller.csv")
df.head()
# Out:
#                                              song                artist  \
# 0                                    Estoy por ti  Amistades Peligrosas
# 1  Vivimos siempre juntos (feat. Mercedes Ferrer)            Nacho Cano
# 2  Vivimos siempre juntos (feat. Mercedes Ferrer)            Nacho Cano
# 3  Vivimos siempre juntos (feat. Mercedes Ferrer)       Mercedes Ferrer
# 4  Vivimos siempre juntos (feat. Mercedes Ferrer)       Mercedes Ferrer
#
#          date  explicit                           uri_cancion  popularity  \
# 0        1991     False  spotify:track:2NCw456Y6nu6RgPotF5tDG          48
# 1  1996-10-14     False  spotify:track:6ijh6CO529euKaq3YfSuCZ          54
# 2  1996-10-14     False  spotify:track:6ijh6CO529euKaq3YfSuCZ          54
# 3  1996-10-14     False  spotify:track:6ijh6CO529euKaq3YfSuCZ          54
# 4  1996-10-14     False  spotify:track:6ijh6CO529euKaq3YfSuCZ          54
#
#                      usuario  \
# 0  oid6yv3v6mpo5t94nn5bqblvq
# ...

# %%
# lo primero que tenemos que mirar es cuántas filas y columnas tenemos en nuestro conjunto de datos
df.shape
# Out:
# (2734, 27)

# %%
print(f"El número de filas es {df.shape[0]}, el número de columnas que tenemos es {df.shape[1]}")
# Out:
# El número de filas es 2734, el número de columnas que tenemos es 27

# %%
# ¿Cuántas canciones tenemos en la lista de existos del 2023?
print("La cantidad de canciones que tenemos en la lista de existos del 2023 es:", len(df["song"].unique()))
# Out:
# La cantidad de canciones que tenemos en la lista de existos del 2023 es: 1380

# %%
# ¿cuantos artistas hay en la lista de top éxitos del 2023?

print("En la lista de reproducción de los existos del 2023 hay:", len(df["artist"].unique()), "artistas")
# Out:
# En la lista de reproducción de los existos del 2023 hay: 976 artistas

# %%
df.head(1)
# Out:
#            song                artist  date  explicit  \
# 0  Estoy por ti  Amistades Peligrosas  1991     False
#
#                             uri_cancion  popularity  \
# 0  spotify:track:2NCw456Y6nu6RgPotF5tDG          48
#
#                      usuario  \
# 0  oid6yv3v6mpo5t94nn5bqblvq
#
#                                                links             uri_artista  \
# 0  https://open.spotify.com/track/2NCw456Y6nu6RgP...  15FscPIs0VO23BCCMaPglf
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.635   0.718    0    -9.626     0       0.0281         0.225
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0               0.0     0.133    0.573  98.006  audio_features
#
#                        id                                   uri  \
# 0  2NCw456Y6nu6RgPotF5tDG  spotify:track:2NCw456Y6nu6RgPotF5tDG
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2NCw456Y6nu6...
#
# ...

# %%
# 
df.isnull().sum()
# Out:
# song                0
# artist              0
# date                0
# explicit            0
# uri_cancion         0
# popularity          0
# usuario             0
# links               0
# uri_artista         0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %% [markdown]
# # Limpieza del conjunto de datos

# %%
# lo primero que podemos ver es que en el dataframe tenemos muchas columnas que a priori no son interesantes para nosotras. Vamos a proceder a eliminarlas
# pero antes de nada ... ¿Cómo podremos saber cual es el nombre de todas las columnas?

df.columns
# Out:
# Index(['song', 'artist', 'date', 'explicit', 'uri_cancion', 'popularity',
#        'usuario', 'links', 'uri_artista', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
# procedamos a eliminar las que no nos interesan
columnas_eliminar = ['tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',  'time_signature', 'mode', "links", "key", "usuario", "uri_artista", "uri_cancion"]
df.drop(columns=columnas_eliminar, inplace=True)

# %%
df.head()
# Out:
#                                              song                artist  \
# 0                                    Estoy por ti  Amistades Peligrosas
# 1  Vivimos siempre juntos (feat. Mercedes Ferrer)            Nacho Cano
# 2  Vivimos siempre juntos (feat. Mercedes Ferrer)            Nacho Cano
# 3  Vivimos siempre juntos (feat. Mercedes Ferrer)       Mercedes Ferrer
# 4  Vivimos siempre juntos (feat. Mercedes Ferrer)       Mercedes Ferrer
#
#          date  explicit  popularity  danceability  energy  loudness  \
# 0        1991     False          48         0.635   0.718    -9.626
# 1  1996-10-14     False          54         0.729   0.709    -9.166
# 2  1996-10-14     False          54         0.729   0.709    -9.166
# 3  1996-10-14     False          54         0.729   0.709    -9.166
# 4  1996-10-14     False          54         0.729   0.709    -9.166
#
#    speechiness  acousticness  instrumentalness  liveness  valence  duration_ms
# ...

# %%
# evaluamos la cantidad de duplicados que hay en nuestro df en base a la columna de song

df.duplicated(subset="song").sum()
# Out:
# 1354

# %%
# eliminamos los duplicados en base a las canciones

df_sin_duplicados = df.drop_duplicates(subset="song", ignore_index=True)

# %%
df_sin_duplicados.head()
# Out:
#                                              song                artist  \
# 0                                    Estoy por ti  Amistades Peligrosas
# 1  Vivimos siempre juntos (feat. Mercedes Ferrer)            Nacho Cano
# 2                            Cuando Brille el Sol            La Guardia
# 3                               Veneno en la Piel          Radio Futura
# 4                       Quiero tener tu presencia      Seguridad Social
#
#          date  explicit  popularity  danceability  energy  loudness  \
# 0        1991     False          48         0.635   0.718    -9.626
# 1  1996-10-14     False          54         0.729   0.709    -9.166
# 2  1990-07-06     False          57         0.505   0.731   -11.379
# 3  1990-03-20     False          57         0.692   0.797   -11.340
# 4        1993     False          62         0.741   0.816    -5.597
#
#    speechiness  acousticness  instrumentalness  liveness  valence  duration_ms
# ...

# %% [markdown]
# ## ¿Qué década es la que mejor música nos ha dado?
#
# Para responder a esta pregunta necesitaremos:
#
# - Sacar de la columna de `date` los años en los que fueron lanzadas las canciones.
#
# - Calcular la década a la que pertencen cada una de las canciones.
#
# - Calcular cuántas canciones hay por década.

# %%
df_sin_duplicados.head()
# Out:
#                                              song                artist  \
# 0                                    Estoy por ti  Amistades Peligrosas
# 1  Vivimos siempre juntos (feat. Mercedes Ferrer)            Nacho Cano
# 2                            Cuando Brille el Sol            La Guardia
# 3                               Veneno en la Piel          Radio Futura
# 4                       Quiero tener tu presencia      Seguridad Social
#
#          date  explicit  popularity  danceability  energy  loudness  \
# 0        1991     False          48         0.635   0.718    -9.626
# 1  1996-10-14     False          54         0.729   0.709    -9.166
# 2  1990-07-06     False          57         0.505   0.731   -11.379
# 3  1990-03-20     False          57         0.692   0.797   -11.340
# 4        1993     False          62         0.741   0.816    -5.597
#
#    speechiness  acousticness  instrumentalness  liveness  valence  duration_ms
# ...

# %%
# convertimos la columna de 'date' a tipo datetime
df_sin_duplicados["date"] = pd.to_datetime(df_sin_duplicados["date"])

# creamos una columna nueva donde solo tengamos el año
df_sin_duplicados["year"] = df_sin_duplicados["date"].dt.year

# calculamos la década a la que pertenece cada cancion
df_sin_duplicados["year"] = df_sin_duplicados['year'] - df_sin_duplicados['year'] % 10
# Out:
# /var/folders/d0/gzh1bx0j04g8wbyd2524690r0000gn/T/ipykernel_26968/1546563902.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados["date"] = pd.to_datetime(df_sin_duplicados["date"])
# /var/folders/d0/gzh1bx0j04g8wbyd2524690r0000gn/T/ipykernel_26968/1546563902.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados["year"] = df_sin_duplicados["date"].dt.year
# ...

# %%
df_sin_duplicados.head()
# Out:
#                                              song                artist  \
# 0                                    Estoy por ti  Amistades Peligrosas
# 1  Vivimos siempre juntos (feat. Mercedes Ferrer)            Nacho Cano
# 2                            Cuando Brille el Sol            La Guardia
# 3                               Veneno en la Piel          Radio Futura
# 4                       Quiero tener tu presencia      Seguridad Social
#
#         date  explicit  popularity  danceability  energy  loudness  \
# 0 1991-01-01     False          48         0.635   0.718    -9.626
# 1 1996-10-14     False          54         0.729   0.709    -9.166
# 2 1990-07-06     False          57         0.505   0.731   -11.379
# 3 1990-03-20     False          57         0.692   0.797   -11.340
# 4 1993-01-01     False          62         0.741   0.816    -5.597
#
#    speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
df_mejor_decada_pop = df_sin_duplicados.groupby("year")["popularity"].mean().reset_index()
df_mejor_decada_pop
# Out:
#    year  popularity
# 0  1950   62.846154
# 1  1960   65.913043
# 2  1970   51.368421
# 3  1980   46.746988
# 4  1990   44.512500
# 5  2000   47.470803
# 6  2010   53.851301
# 7  2020   54.824561

# %%
plt.figure(figsize = (20, 5))
sns.barplot(x = "year", y = "popularity", data = df_mejor_decada_pop, palette= "viridis", edgecolor = "black");

# %% [markdown]
# ## ¿Por qué los 60?

# %%
decada = int(input("¿De qué década quieres explorar la música?"))
print(f"El año que has elegido es {decada}")
# Out:
# El año que has elegido es 1960

# %%
df_decada = df_sin_duplicados[df_sin_duplicados["year"] == decada]
df_decada.head(10)
# Out:
#                                       song                        artist  \
# 837     Black Magic Woman - Single Version                       Santana
# 847                       I Started A Joke                      Bee Gees
# 873       And I Love Her - Remastered 2009                   The Beatles
# 903                     Down On The Corner  Creedence Clearwater Revival
# 904                             Proud Mary  Creedence Clearwater Revival
# 912           Love Me Do - Remastered 2009                   The Beatles
# 915            Yesterday - Remastered 2009                   The Beatles
# 924                       To Love Somebody                      Bee Gees
# 1304         Oh! Darling - Remastered 2009                   The Beatles
# 1319  California Dreamin' - Single Version         The Mamas & The Papas
#
#            date  explicit  popularity  danceability  energy  loudness  \
# 837  1969-01-01     False          69         0.489   0.349   -14.295
# ...

# %%
# ¿Cuántas canciones tenemos de cada uno de los artistas?
df_canciones_artista = df_decada.groupby("artist")["popularity"].mean().reset_index()
df_canciones_artista.sort_values(by="popularity", ascending=False, inplace=True)
df_canciones_artista.head()
# Out:
#                           artist  popularity
# 24            The Rolling Stones        80.5
# 21         The Mamas & The Papas        80.0
# 2   Creedence Clearwater Revival        79.0
# 23        The Righteous Brothers        76.0
# 12             Simon & Garfunkel        75.0

# %%
plt.figure(figsize = (20,5))
sns.barplot(x = "artist", y = "popularity", data = df_canciones_artista, palette = "viridis")
plt.xticks(rotation=90, ha='center');

# %%
df_sin_duplicados.head(1)
# Out:
#            song                artist       date  explicit  popularity  \
# 0  Estoy por ti  Amistades Peligrosas 1991-01-01     False          48
#
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.635   0.718    -9.626       0.0281         0.225
#
#    instrumentalness  liveness  valence  duration_ms  year
# 0               0.0     0.133    0.573       284067  1990

# %%
columnas_viz = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence']

fig, axes = plt.subplots(nrows = 2, ncols = 4, figsize = (20,5))
axes = axes.flat
for indice, columna in enumerate(columnas_viz):
    sns.lineplot(x = "year", y = columna, data = df_sin_duplicados, ax = axes[indice], color = "teal" )

fig.tight_layout()

# %% [markdown]
# ### ¿Qué géneros dominan?

# %%
df_artistas = pd.read_csv("../data/artistas_taller.csv" )
df_artistas.head()
# Out:
#     artist_name               artist_id  followers  \
# 0       Rihanna  5pKCCKE2ajJHZ9KAiaK11H   54752804
# 1         JAY-Z  3nFkdlSjzX9mRTtwJOzDYB    8330852
# 2   Miley Cyrus  5YGY8feqx7naU7z4HrwZM6   20548132
# 3  Nena Daconte  58ZTr51uERVdMQbfDbc5B3     157076
# 4     Lady Gaga  1HY2Jd0NmPuamShAr6KMms   26207886
#
#                                               genres  popularity
# 0     ['barbadian pop', 'pop', 'urban contemporary']          91
# 1  ['east coast hip hop', 'gangster rap', 'hip ho...          85
# 2                                            ['pop']          90
# 3                                    ['spanish pop']          52
# 4                    ['art pop', 'dance pop', 'pop']          86

# %%
df_decada.head(1)
# Out:
#                                    song   artist       date  explicit  \
# 837  Black Magic Woman - Single Version  Santana 1969-01-01     False
#
#      popularity  danceability  energy  loudness  speechiness  acousticness  \
# 837          69         0.489   0.349   -14.295       0.0323         0.676
#
#      instrumentalness  liveness  valence  duration_ms  year
# 837            0.0789    0.0866    0.622       196467  1960

# %%
artistas_decada = df_decada["artist"].unique().tolist()
artistas_decada[:5]
# Out:
# ['Santana',
#  'Bee Gees',
#  'The Beatles',
#  'Creedence Clearwater Revival',
#  'The Mamas & The Papas']

# %%
df_artistas_decada = df_artistas[df_artistas["artist_name"].isin(artistas_decada)]
df_artistas_decada.head()
# Out:
#                 artist_name               artist_id  followers  \
# 183   The Mamas & The Papas  1bs7HoMkSyQwcobCpE9KpN    1530968
# 184          Scott McKenzie  7d7AZ3CQC457bFhK0wHpSO      40887
# 185             Roy Orbison  0JDkhL4rjiPNEp92jAgJnS    1771907
# 186  The Righteous Brothers  4b0WsB47XCa9F83BmwQ7WX     526741
# 187          The Beach Boys  3oDbviiivRWhXwIE8hxkVV    4084507
#
#                                                 genres  popularity
# 183  ['classic rock', 'folk', 'folk rock', 'mellow ...          68
# 184                                                 []          51
# 185  ['adult standards', 'classic rock', 'folk rock...          66
# 186  ['adult standards', 'brill building pop', 'fol...          62
# 187  ['baroque pop', 'classic rock', 'folk rock', '...          73

# %%
import ast
df_artistas_decada["genres"] = df_artistas_decada["genres"].apply(ast.literal_eval)
# Out:
# /var/folders/d0/gzh1bx0j04g8wbyd2524690r0000gn/T/ipykernel_26968/2343317976.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_artistas_decada["genres"] = df_artistas_decada["genres"].apply(ast.literal_eval)

# %%
df_artistas_decada = df_artistas_decada.explode("genres")
df_artistas_decada.head()
# Out:
#                artist_name               artist_id  followers  \
# 183  The Mamas & The Papas  1bs7HoMkSyQwcobCpE9KpN    1530968
# 183  The Mamas & The Papas  1bs7HoMkSyQwcobCpE9KpN    1530968
# 183  The Mamas & The Papas  1bs7HoMkSyQwcobCpE9KpN    1530968
# 183  The Mamas & The Papas  1bs7HoMkSyQwcobCpE9KpN    1530968
# 183  The Mamas & The Papas  1bs7HoMkSyQwcobCpE9KpN    1530968
#
#                genres  popularity
# 183      classic rock          68
# 183              folk          68
# 183         folk rock          68
# 183       mellow gold          68
# 183  psychedelic rock          68

# %%
df_artistas_decada.isnull().sum()
# Out:
# artist_name    0
# artist_id      0
# followers      0
# genres         1
# popularity     0
# dtype: int64

# %%
df_artistas_decada.dropna(inplace = True)

# %%
from wordcloud import WordCloud, STOPWORDS

# Joining all the words in the description column into one string.
text = " ".join(cat for cat in df_artistas_decada["genres"])

word_cloud = WordCloud(
    width=7000,
    height=2000,
    background_color="black",
    colormap="OrRd",
    collocations=True,
    stopwords=STOPWORDS,
    ).generate(text)

# Showing the word cloud.
plt.imshow(word_cloud)


# Turning off the axis.
plt.axis("off")

# Showing the word cloud.
plt.show()
